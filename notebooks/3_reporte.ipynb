# %%
import getpass 
from sqlalchemy import create_engine

# %%
password = getpass.getpass(" Introduce tu contraseña de MySQL: ")
db_name = "videogames"

# %%
connection_string = f'mysql+pymysql://root:{password}@localhost:3306/{db_name}'
engine = create_engine(connection_string)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Identificación de facturación por región y facturación global por género desde 2015 hasta 2024.


query1 = """SELECT
s.genre,
ROUND(SUM(s.na_sales),2) as ventas_norteamerica,
ROUND(SUM(s.jp_sales),2) as ventas_japon,
ROUND(SUM(s.pal_sales),2) as ventas_europa_africa,
ROUND(SUM(s.other_sales),2) as otras_regiones,
ROUND(SUM(s.total_sales),2) as ventas_totales
FROM sales as s
INNER JOIN metacritic m on s.title = m.title
WHERE m.release_date >= '2015-01-01'
GROUP BY s.genre
ORDER BY ventas_totales DESC; """
df1 = pd.read_sql(query1, engine)
df1
# Out:
#                genre  ventas_norteamerica  ventas_japon  ventas_europa_africa  \
# 0             Sports                66.15          2.83                 61.15
# 1            Shooter                69.84          3.79                 52.51
# 2             Action                43.38          8.55                 36.43
# 3       Role-Playing                25.34         15.23                 18.84
# 4   Action-Adventure                25.93          1.93                 24.11
# 5             Racing                 8.57          0.74                 12.78
# 6               Misc                12.06          1.13                  7.56
# 7           Platform                 8.30          0.88                  9.03
# 8           Fighting                10.06          2.64                  4.77
# 9              Music                 7.63          0.53                  5.11
# 10        Simulation                 6.51          0.63                  5.64
# 11         Adventure                 5.85          2.50                  3.81
# 12          Strategy                 2.14          0.50                  1.72
# 13               MMO                 2.12          0.11                  1.72
# 14            Puzzle                 1.33          0.99                  0.67
# 15             Party                 0.80          0.54                  1.13
# 16      Visual Novel                 0.34          0.74                  0.10
# 17        Board Game                 0.00          0.00                  0.00
# 18           Sandbox                 0.00          0.00                  0.00
#
#     otras_regiones  ventas_totales
# 0            20.31          150.50
# 1            18.00          144.01
# 2            12.29          100.78
# 3             7.25           66.66
# 4             7.93           59.92
# 5             2.97           25.15
# 6             1.69           22.45
# 7             2.61           20.85
# 8             2.52           20.02
# 9             1.68           14.96
# 10            1.16           14.00
# 11            1.46           13.66
# 12            0.42            4.74
# 13            0.59            4.55
# 14            0.26            3.25
# 15            0.23            2.70
# 16            0.10            1.31
# 17            0.00            0.00
# 18            0.00            0.00

# %%
# Relación entre ventas por genero y crítica ( meta_score y user_score)desde 2015 hasta 2024 ordenado por total ventas.

query2 = """SELECT
s.genre,
ROUND(SUM(s.total_sales),2) AS total_ventas_millones,
ROUND(AVG(m.meta_score),2) AS nota_meta,
ROUND(AVG(m.user_score),2) AS nota_user,
COUNT(s.title) AS cantidad_juegos
FROM sales as s
INNER JOIN metacritic m on s.title = m.title
WHERE m.release_date >= '2015-01-01'
GROUP BY s.genre
HAVING cantidad_juegos >= 5
ORDER BY total_ventas_millones DESC;"""
df2 = pd.read_sql(query2, engine)
df2
# Out:
#                genre  total_ventas_millones  nota_meta  nota_user  \
# 0             Sports                 150.50      71.79      53.61
# 1            Shooter                 144.01      71.31      60.91
# 2             Action                 100.78      71.76      67.42
# 3       Role-Playing                  66.66      74.24      70.66
# 4   Action-Adventure                  59.92      74.28      69.10
# 5             Racing                  25.15      71.43      59.82
# 6               Misc                  22.45      71.77      62.95
# 7           Platform                  20.85      74.43      70.58
# 8           Fighting                  20.02      73.18      66.29
# 9              Music                  14.96      75.11      68.29
# 10        Simulation                  14.00      72.77      66.54
# 11         Adventure                  13.66      73.18      67.91
# 12          Strategy                   4.74      74.63      67.89
# 13               MMO                   4.55      80.72      66.22
# 14            Puzzle                   3.25      75.25      65.58
# 15             Party                   2.70      69.83      62.07
# 16      Visual Novel                   1.31      76.68      74.55
# 17        Board Game                   0.00      66.33      63.17
#
#     cantidad_juegos
# 0               117
# 1               261
# 2               451
# 3               404
# 4               299
# 5               127
# 6                88
# 7               154
# 8                93
# 9                41
# 10              133
# 11              331
# 12              183
# 13               18
# 14              121
# 15               30
# 16               31
# 17                6

# %%
# Relación entre ventas por genero y crítica desde 2015 hasta 2024 ordenado por metacritic.



query3 = """SELECT
s.genre,
ROUND(SUM(s.total_sales),2) AS total_ventas_millones,
ROUND(AVG(m.meta_score),2) AS nota_meta,
ROUND(AVG(m.user_score),2) AS nota_user,
COUNT(s.title) AS cantidad_juegos
FROM sales as s
INNER JOIN metacritic m on s.title = m.title
WHERE m.release_date >= '2015-01-01'
GROUP BY s.genre
HAVING cantidad_juegos >= 5
ORDER BY nota_meta DESC;"""
df_3 = pd.read_sql(query3, engine)
df_3
# Out:
#                genre  total_ventas_millones  nota_meta  nota_user  \
# 0                MMO                   4.55      80.72      66.22
# 1       Visual Novel                   1.31      76.68      74.55
# 2             Puzzle                   3.25      75.25      65.58
# 3              Music                  14.96      75.11      68.29
# 4           Strategy                   4.74      74.63      67.89
# 5           Platform                  20.85      74.43      70.58
# 6   Action-Adventure                  59.92      74.28      69.10
# 7       Role-Playing                  66.66      74.24      70.66
# 8           Fighting                  20.02      73.18      66.29
# 9          Adventure                  13.66      73.18      67.91
# 10        Simulation                  14.00      72.77      66.54
# 11            Sports                 150.50      71.79      53.61
# 12              Misc                  22.45      71.77      62.95
# 13            Action                 100.78      71.76      67.42
# 14            Racing                  25.15      71.43      59.82
# 15           Shooter                 144.01      71.31      60.91
# 16             Party                   2.70      69.83      62.07
# 17        Board Game                   0.00      66.33      63.17
#
#     cantidad_juegos
# 0                18
# 1                31
# 2               121
# 3                41
# 4               183
# 5               154
# 6               299
# 7               404
# 8                93
# 9               331
# 10              133
# 11              117
# 12               88
# 13              451
# 14              127
# 15              261
# 16               30
# 17                6

# %%
# Relación entre ventas por genero y crítica desde 2015 hasta 2024 ordenado por user_score

query4 = """SELECT
s.genre,
ROUND(SUM(s.total_sales),2) AS total_ventas_millones,
ROUND(AVG(m.meta_score),2) AS nota_meta,
ROUND(AVG(m.user_score),2) AS nota_user,
COUNT(s.title) AS cantidad_juegos
FROM sales as s
INNER JOIN metacritic m on s.title = m.title
WHERE m.release_date >= '2015-01-01'
GROUP BY s.genre
HAVING cantidad_juegos >= 5
ORDER BY nota_user DESC;"""
df4 = pd.read_sql(query4, engine)
df4
# Out:
#                genre  total_ventas_millones  nota_meta  nota_user  \
# 0       Visual Novel                   1.31      76.68      74.55
# 1       Role-Playing                  66.66      74.24      70.66
# 2           Platform                  20.85      74.43      70.58
# 3   Action-Adventure                  59.92      74.28      69.10
# 4              Music                  14.96      75.11      68.29
# 5          Adventure                  13.66      73.18      67.91
# 6           Strategy                   4.74      74.63      67.89
# 7             Action                 100.78      71.76      67.42
# 8         Simulation                  14.00      72.77      66.54
# 9           Fighting                  20.02      73.18      66.29
# 10               MMO                   4.55      80.72      66.22
# 11            Puzzle                   3.25      75.25      65.58
# 12        Board Game                   0.00      66.33      63.17
# 13              Misc                  22.45      71.77      62.95
# 14             Party                   2.70      69.83      62.07
# 15           Shooter                 144.01      71.31      60.91
# 16            Racing                  25.15      71.43      59.82
# 17            Sports                 150.50      71.79      53.61
#
#     cantidad_juegos
# 0                31
# 1               404
# 2               154
# 3               299
# 4                41
# 5               331
# 6               183
# 7               451
# 8               133
# 9                93
# 10               18
# 11              121
# 12                6
# 13               88
# 14               30
# 15              261
# 16              127
# 17              117

# %%
# Porcentaje de riesgo según total de ventas por género en Japón desde 2015 hasta 2024 .

query5 = """SELECT 
s.genre,
ROUND(SUM(s.jp_sales),2) AS ventas_japon_millones,
ROUND(SUM(s.total_sales),2) AS ventas_totales_millones,
ROUND(SUM(s.jp_sales)/ sum(s.total_sales) *100, 2) AS dependecia_japon
FROM sales AS s
INNER JOIN metacritic as m
on s.title = m.title
where m. release_date >= '2015-01-01'
GROUP BY genre
HAVING ventas_totales_millones > 1
ORDER BY dependecia_japon DESC;"""
df5 = pd.read_sql(query5, engine)
df5
# Out:
#                genre  ventas_japon_millones  ventas_totales_millones  \
# 0       Visual Novel                   0.74                     1.31
# 1             Puzzle                   0.99                     3.25
# 2       Role-Playing                  15.23                    66.66
# 3              Party                   0.54                     2.70
# 4          Adventure                   2.50                    13.66
# 5           Fighting                   2.64                    20.02
# 6           Strategy                   0.50                     4.74
# 7             Action                   8.55                   100.78
# 8               Misc                   1.13                    22.45
# 9         Simulation                   0.63                    14.00
# 10          Platform                   0.88                    20.85
# 11             Music                   0.53                    14.96
# 12  Action-Adventure                   1.93                    59.92
# 13            Racing                   0.74                    25.15
# 14           Shooter                   3.79                   144.01
# 15               MMO                   0.11                     4.55
# 16            Sports                   2.83                   150.50
#
#     dependecia_japon
# 0              56.49
# 1              30.46
# 2              22.85
# 3              20.00
# 4              18.30
# 5              13.19
# 6              10.55
# 7               8.48
# 8               5.03
# 9               4.50
# 10              4.22
# 11              3.54
# 12              3.22
# 13              2.94
# 14              2.63
# 15              2.42
# 16              1.88

# %%
# Porcentaje de riesgo según total de ventas por género en Japón desde 2015 hasta 2024 .

SELECT

query6 = """SELECT
s.title AS titulo,
s.genre AS genero,
s.sales_non_japan AS ventas_no_japon,
m.meta_score AS meta_critica,
m.user_score AS user_critica
FROM sales AS s
INNER JOIN metacritic AS m
on s.title = m.title
WHERE release_date >= '2015-1-1'
AND s.total_sales > 1
AND m.meta_score >=70
AND m.user_score >=70
ORDER BY ventas_no_japon DESC
LIMIT 31;"""
df6 = pd.read_sql(query6, engine)
df6
# Out:
#                                         titulo            genero  \
# 0                        red dead redemption 2  Action-Adventure
# 1                                    fallout 4      Role-Playing
# 2                                battlefield 1           Shooter
# 3                                 namco museum              Misc
# 4                     tom clancys the division           Shooter
# 5                tom clancys rainbow six siege           Shooter
# 6               crash bandicoot n sane trilogy          Platform
# 7                      assassins creed origins            Action
# 8                          lego jurassic world            Action
# 9                         batman arkham knight            Action
# 10                             mortal kombat x          Fighting
# 11                            final fantasy xv      Role-Playing
# 12  the elder scrolls v skyrim special edition      Role-Playing
# 13                  microsoft flight simulator        Simulation
# 14                                watch dogs 2            Action
# 15                             lego dimensions            Action
# 16                                  dead space           Shooter
# 17                               rocket league            Sports
# 18                                 dying light            Action
# 19         metal gear solid v the phantom pain            Action
# 20  the elder scrolls online tamriel unlimited               MMO
# 21                              gears of war 4           Shooter
# 22                                 titanfall 2           Shooter
# 23                                dishonored 2            Action
# 24                       lego marvels avengers            Action
# 25            lego star wars the force awakens  Action-Adventure
# 26                                    wwe 2k16            Sports
# 27                     spyro reignited trilogy          Platform
# 28                                 injustice 2          Fighting
# 29                   shadow of the tomb raider  Action-Adventure
# 30                     rise of the tomb raider         Adventure
#
#     ventas_no_japon  meta_critica  user_critica
# 0             19.50          97.0          89.0
# 1             13.23          87.0          70.0
# 2             12.85          88.0          74.0
# 3              7.55          72.0          74.0
# 4              7.30          80.0          70.0
# 5              7.00          73.0          70.0
# 6              6.50          80.0          84.0
# 7              6.44          81.0          73.0
# 8              5.59          70.0          73.0
# 9              5.56          87.0          81.0
# 10             5.29          83.0          77.0
# 11             5.15          81.0          74.0
# 12             5.11          84.0          83.0
# 13             5.11          91.0          72.0
# 14             4.60          82.0          76.0
# 15             4.23          80.0          73.0
# 16             4.01          89.0          84.0
# 17             3.92          85.0          81.0
# 18             3.78          74.0          80.0
# 19             3.51          93.0          81.0
# 20             3.43          74.0          75.0
# 21             3.39          84.0          71.0
# 22             3.22          89.0          85.0
# 23             3.08          88.0          80.0
# 24             3.08          71.0          72.0
# 25             3.04          78.0          71.0
# 26             2.95          73.0          72.0
# 27             2.83          82.0          83.0
# 28             2.61          87.0          79.0
# 29             2.46          75.0          73.0
# 30             2.37          86.0          81.0

# %%
#  Identificación de juegos con éxito comercial (mas 1 millones) y éxito en critica ( igual o mas 70) en  japon

query7 = """SELECT
s.title AS titulo,
s.genre AS genero,
s.jp_sales  ventas_japon,
m.meta_score AS meta_critica,
m.user_score AS user_critica
FROM sales AS s
INNER JOIN metacritic AS m
on s.title = m.title
WHERE release_date >= '2015-1-1'
AND s.total_sales > 1
AND m.meta_score >=70
AND m.user_score >=70
ORDER BY ventas_japon DESC;"""
df7 = pd.read_sql(query7, engine)
df7
# Out:
#                                         titulo            genero  \
# 0     dragon quest xi echoes of an elusive age      Role-Playing
# 1                             final fantasy xv      Role-Playing
# 2                                    persona 5      Role-Playing
# 3          metal gear solid v the phantom pain            Action
# 4                tom clancys rainbow six siege           Shooter
# 5                  resident evil revelations 2            Action
# 6                                battlefield 1           Shooter
# 7                    pro evolution soccer 2016            Sports
# 8                                    fallout 4      Role-Playing
# 9                       shadow of the colossus  Action-Adventure
# 10                        xenoblade chronicles      Role-Playing
# 11                   pro evolution soccer 2017            Sports
# 12                       red dead redemption 2  Action-Adventure
# 13                    tom clancys the division           Shooter
# 14                                 dying light            Action
# 15                           the last guardian  Action-Adventure
# 16                                watch dogs 2            Action
# 17                     assassins creed origins            Action
# 18                        batman arkham knight            Action
# 19              crash bandicoot n sane trilogy          Platform
# 20                         lego jurassic world            Action
# 21                           the evil within 2            Action
# 22  the elder scrolls v skyrim special edition      Role-Playing
# 23            lego star wars the force awakens  Action-Adventure
# 24                                 titanfall 2           Shooter
# 25                   shadow of the tomb raider  Action-Adventure
# 26                                      hitman            Action
# 27                                namco museum              Misc
# 28                       lego marvels avengers            Action
# 29                     rise of the tomb raider         Adventure
# 30                                project cars            Racing
# 31         borderlands the handsome collection           Shooter
# 32                     bioshock the collection           Shooter
# 33         assassins creed the ezio collection            Action
# 34                             forza horizon 4            Racing
# 35                                dishonored 2            Action
# 36             wolfenstein ii the new colossus           Shooter
# 37               the elder scrolls v skyrim vr      Role-Playing
# 38                     deus ex mankind divided      Role-Playing
# 39  the elder scrolls online tamriel unlimited               MMO
# 40                               rocket league            Sports
# 41                                  dead space           Shooter
# 42                             lego dimensions            Action
# 43                  microsoft flight simulator        Simulation
# 44          plants vs zombies garden warfare 2           Shooter
# 45                             mortal kombat x          Fighting
# 46                                 injustice 2          Fighting
# 47                                    wwe 2k16            Sports
# 48                lego harry potter collection            Action
# 49                          destroy all humans         Adventure
# 50                              gears of war 4           Shooter
# 51          south park the fractured but whole      Role-Playing
# 52                       lego dc supervillains  Action-Adventure
# 53                     spyro reignited trilogy          Platform
# 54                             mlb 15 the show            Sports
#
#     ventas_japon  meta_critica  user_critica
# 0           1.43          86.0          84.0
# 1           1.06          81.0          74.0
# 2           0.62          93.0          89.0
# 3           0.52          93.0          81.0
# 4           0.36          73.0          70.0
# 5           0.36          75.0          76.0
# 6           0.31          88.0          74.0
# 7           0.30          87.0          72.0
# 8           0.29          87.0          70.0
# 9           0.29          91.0          78.0
# 10          0.29          86.0          84.0
# 11          0.26          85.0          74.0
# 12          0.21          97.0          89.0
# 13          0.16          80.0          70.0
# 14          0.14          74.0          80.0
# 15          0.13          82.0          80.0
# 16          0.12          82.0          76.0
# 17          0.11          81.0          73.0
# 18          0.11          87.0          81.0
# 19          0.09          80.0          84.0
# 20          0.09          70.0          73.0
# 21          0.09          76.0          81.0
# 22          0.08          84.0          83.0
# 23          0.08          78.0          71.0
# 24          0.06          89.0          85.0
# 25          0.06          75.0          73.0
# 26          0.06          84.0          78.0
# 27          0.05          72.0          74.0
# 28          0.05          71.0          72.0
# 29          0.05          86.0          81.0
# 30          0.04          83.0          72.0
# 31          0.03          82.0          78.0
# 32          0.03          84.0          86.0
# 33          0.02          72.0          82.0
# 34          0.01          92.0          83.0
# 35          0.01          88.0          80.0
# 36          0.01          87.0          74.0
# 37          0.01          77.0          81.0
# 38          0.01          84.0          77.0
# 39          0.00          74.0          75.0
# 40          0.00          85.0          81.0
# 41          0.00          89.0          84.0
# 42          0.00          80.0          73.0
# 43          0.00          91.0          72.0
# 44          0.00          80.0          83.0
# 45          0.00          83.0          77.0
# 46          0.00          87.0          79.0
# 47          0.00          73.0          72.0
# 48          0.00          73.0          74.0
# 49          0.00          70.0          77.0
# 50          0.00          84.0          71.0
# 51          0.00          79.0          78.0
# 52          0.00          74.0          73.0
# 53          0.00          82.0          83.0
# 54          0.00          80.0          77.0
